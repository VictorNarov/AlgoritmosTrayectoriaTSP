# %% [markdown]
# # Algoritmo Enfriamiento Simulado

# %%
from ipynb.fs.full.algoritmos import *

# %% [markdown]
# ## Generación de semillas aleatorias

# %%
semillas = []
for i in range(10):
    semillas.append(random.randint(0,9999999))

# %% [markdown]
# ## Fichero st70

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "st70"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: st70
# Limite iteraciones: 5600
# Tiempo de ejecución: 1.961500
#
# 1)	Coste: 950 	 #EV: 112001 	 Semilla: 6855880
# 2)	Coste: 1126 	 #EV: 112001 	 Semilla: 9635826
# 3)	Coste: 1054 	 #EV: 112001 	 Semilla: 1328515
# 4)	Coste: 900 	 #EV: 112001 	 Semilla: 5494183
# 5)	Coste: 1094 	 #EV: 112001 	 Semilla: 9816694
# 6)	Coste: 910 	 #EV: 112001 	 Semilla: 5027992
# 7)	Coste: 955 	 #EV: 112001 	 Semilla: 3628315
# 8)	Coste: 976 	 #EV: 112001 	 Semilla: 1355206
# 9)	Coste: 1121 	 #EV: 112001 	 Semilla: 2439335
# 10)	Coste: 916 	 #EV: 112001 	 Semilla: 9974473
# -----
# Coste Media:	1000.200000 	 Desv: 89.768591
# #Ev Media:	112001.000000 	 Desv: 0.000000
# Mejor solución de coste:  900

# %% [markdown]
# ## Fichero ch130

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "ch130"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: ch130
# Limite iteraciones: 10400
# Tiempo de ejecución: 3.236504
#
# 1)	Coste: 10560 	 #EV: 208001 	 Semilla: 6855880
# 2)	Coste: 11910 	 #EV: 208001 	 Semilla: 9635826
# 3)	Coste: 11424 	 #EV: 208001 	 Semilla: 1328515
# 4)	Coste: 9981 	 #EV: 208001 	 Semilla: 5494183
# 5)	Coste: 11193 	 #EV: 208001 	 Semilla: 9816694
# 6)	Coste: 11160 	 #EV: 208001 	 Semilla: 5027992
# 7)	Coste: 11559 	 #EV: 208001 	 Semilla: 3628315
# 8)	Coste: 10737 	 #EV: 208001 	 Semilla: 1355206
# 9)	Coste: 10357 	 #EV: 208001 	 Semilla: 2439335
# 10)	Coste: 10434 	 #EV: 208001 	 Semilla: 9974473
# -----
# Coste Media:	10931.500000 	 Desv: 612.029275
# #Ev Media:	208001.000000 	 Desv: 0.000000
# Mejor solución de coste:  9981

# %% [markdown]
# ## Fichero a280

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "a280"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: a280
# Limite iteraciones: 22400
# Tiempo de ejecución: 5.482499
#
# 1)	Coste: 6048 	 #EV: 448001 	 Semilla: 6855880
# 2)	Coste: 6314 	 #EV: 448001 	 Semilla: 9635826
# 3)	Coste: 6781 	 #EV: 448001 	 Semilla: 1328515
# 4)	Coste: 6315 	 #EV: 448001 	 Semilla: 5494183
# 5)	Coste: 6218 	 #EV: 448001 	 Semilla: 9816694
# 6)	Coste: 6418 	 #EV: 448001 	 Semilla: 5027992
# 7)	Coste: 5521 	 #EV: 448001 	 Semilla: 3628315
# 8)	Coste: 5856 	 #EV: 448001 	 Semilla: 1355206
# 9)	Coste: 5236 	 #EV: 448001 	 Semilla: 2439335
# 10)	Coste: 5974 	 #EV: 448001 	 Semilla: 9974473
# -----
# Coste Media:	6068.100000 	 Desv: 449.753871
# #Ev Media:	448001.000000 	 Desv: 0.000000
# Mejor solución de coste:  5236

# %% [markdown]
# ## Fichero p654

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "p654"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: p654
# Limite iteraciones: 52320
# Tiempo de ejecución: 13.197999
#
# 1)	Coste: 318852 	 #EV: 1046401 	 Semilla: 6855880
# 2)	Coste: 342624 	 #EV: 1046401 	 Semilla: 9635826
# 3)	Coste: 320283 	 #EV: 1046401 	 Semilla: 1328515
# 4)	Coste: 307500 	 #EV: 1046401 	 Semilla: 5494183
# 5)	Coste: 374388 	 #EV: 1046401 	 Semilla: 9816694
# 6)	Coste: 322763 	 #EV: 1046401 	 Semilla: 5027992
# 7)	Coste: 355828 	 #EV: 1046401 	 Semilla: 3628315
# 8)	Coste: 349229 	 #EV: 1046401 	 Semilla: 1355206
# 9)	Coste: 367920 	 #EV: 1046401 	 Semilla: 2439335
# 10)	Coste: 389706 	 #EV: 1046401 	 Semilla: 9974473
# -----
# Coste Media:	344909.300000 	 Desv: 27332.688363
# #Ev Media:	1046401.000000 	 Desv: 0.000000
# Mejor solución de coste:  307500

# %% [markdown]
# ## Fichero vm1084

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "vm1084"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: vm1084
# Limite iteraciones: 86720
# Tiempo de ejecución: 23.293002
#
# 1)	Coste: 1300005 	 #EV: 1734401 	 Semilla: 6855880
# 2)	Coste: 1398311 	 #EV: 1734401 	 Semilla: 9635826
# 3)	Coste: 1322923 	 #EV: 1734401 	 Semilla: 1328515
# 4)	Coste: 1233144 	 #EV: 1734401 	 Semilla: 5494183
# 5)	Coste: 1292924 	 #EV: 1734401 	 Semilla: 9816694
# 6)	Coste: 1306309 	 #EV: 1734401 	 Semilla: 5027992
# 7)	Coste: 1286527 	 #EV: 1734401 	 Semilla: 3628315
# 8)	Coste: 1237837 	 #EV: 1734401 	 Semilla: 1355206
# 9)	Coste: 1277652 	 #EV: 1734401 	 Semilla: 2439335
# 10)	Coste: 1287425 	 #EV: 1734401 	 Semilla: 9974473
# -----
# Coste Media:	1294305.700000 	 Desv: 46102.769464
# #Ev Media:	1734401.000000 	 Desv: 0.000000
# Mejor solución de coste:  1233144

# %% [markdown]
# ## Fichero vm1748

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "vm1748"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: vm1748
# Limite iteraciones: 139840
# Tiempo de ejecución: 40.314501
#
# 1)	Coste: 2215078 	 #EV: 2796801 	 Semilla: 6855880
# 2)	Coste: 2398102 	 #EV: 2796801 	 Semilla: 9635826
# 3)	Coste: 2356964 	 #EV: 2796801 	 Semilla: 1328515
# 4)	Coste: 2245650 	 #EV: 2796801 	 Semilla: 5494183
# 5)	Coste: 2308416 	 #EV: 2796801 	 Semilla: 9816694
# 6)	Coste: 2260814 	 #EV: 2796801 	 Semilla: 5027992
# 7)	Coste: 2279721 	 #EV: 2796801 	 Semilla: 3628315
# 8)	Coste: 2209846 	 #EV: 2796801 	 Semilla: 1355206
# 9)	Coste: 2203989 	 #EV: 2796801 	 Semilla: 2439335
# 10)	Coste: 2272878 	 #EV: 2796801 	 Semilla: 9974473
# -----
# Coste Media:	2275145.800000 	 Desv: 64080.092178
# #Ev Media:	2796801.000000 	 Desv: 0.000000
# Mejor solución de coste:  2203989

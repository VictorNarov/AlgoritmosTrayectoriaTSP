# %% [markdown]
# # Algoritmo Enfriamiento Simulado

# %%
from ipynb.fs.full.algoritmos import *

# %% [markdown]
# ## Generación de semillas aleatorias

# %%
semillas = []
for i in range(10):
    semillas.append(random.randint(0,9999999))

# %% [markdown]
# ## Fichero st70

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "st70"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: st70
# Limite iteraciones: 5600
# Tiempo de ejecución: 1.844501
#
# 1)	Coste: 998 	 #EV: 5600 	 Semilla: 3321726
# 2)	Coste: 1009 	 #EV: 5600 	 Semilla: 5522762
# 3)	Coste: 1090 	 #EV: 5600 	 Semilla: 9235856
# 4)	Coste: 1024 	 #EV: 5600 	 Semilla: 7498743
# 5)	Coste: 1177 	 #EV: 5600 	 Semilla: 8317048
# 6)	Coste: 1095 	 #EV: 5600 	 Semilla: 2044754
# 7)	Coste: 1151 	 #EV: 5600 	 Semilla: 2678273
# 8)	Coste: 1035 	 #EV: 5600 	 Semilla: 3758093
# 9)	Coste: 981 	 #EV: 5600 	 Semilla: 9969938
# 10)	Coste: 1043 	 #EV: 5600 	 Semilla: 4904922
# -----
# Coste Media:	1060.300000 	 Desv: 65.819703
# #Ev Media:	5600.000000 	 Desv: 0.000000
# Mejor solución de coste:  981

# %% [markdown]
# ## Fichero ch130

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "ch130"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: ch130
# Limite iteraciones: 10400
# Tiempo de ejecución: 2.827999
#
# 1)	Coste: 9937 	 #EV: 10400 	 Semilla: 60564
# 2)	Coste: 11002 	 #EV: 10400 	 Semilla: 4172274
# 3)	Coste: 9562 	 #EV: 10400 	 Semilla: 8709592
# 4)	Coste: 10998 	 #EV: 10400 	 Semilla: 8674316
# 5)	Coste: 10077 	 #EV: 10400 	 Semilla: 7927296
# 6)	Coste: 10098 	 #EV: 10400 	 Semilla: 3604392
# 7)	Coste: 11488 	 #EV: 10400 	 Semilla: 4625181
# 8)	Coste: 11419 	 #EV: 10400 	 Semilla: 8620343
# 9)	Coste: 11033 	 #EV: 10400 	 Semilla: 1024116
# 10)	Coste: 10604 	 #EV: 10400 	 Semilla: 610738
# -----
# Coste Media:	10621.800000 	 Desv: 667.050856
# #Ev Media:	10400.000000 	 Desv: 0.000000
# Mejor solución de coste:  9562

# %% [markdown]
# ## Fichero a280

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "a280"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: a280
# Limite iteraciones: 22400
# Tiempo de ejecución: 5.103499
#
# 1)	Coste: 6322 	 #EV: 22400 	 Semilla: 60564
# 2)	Coste: 6105 	 #EV: 22400 	 Semilla: 4172274
# 3)	Coste: 6418 	 #EV: 22400 	 Semilla: 8709592
# 4)	Coste: 6394 	 #EV: 22400 	 Semilla: 8674316
# 5)	Coste: 6671 	 #EV: 22400 	 Semilla: 7927296
# 6)	Coste: 6457 	 #EV: 22400 	 Semilla: 3604392
# 7)	Coste: 6105 	 #EV: 22400 	 Semilla: 4625181
# 8)	Coste: 6555 	 #EV: 22400 	 Semilla: 8620343
# 9)	Coste: 6580 	 #EV: 22400 	 Semilla: 1024116
# 10)	Coste: 6782 	 #EV: 22400 	 Semilla: 610738
# -----
# Coste Media:	6438.900000 	 Desv: 222.211336
# #Ev Media:	22400.000000 	 Desv: 0.000000
# Mejor solución de coste:  6105

# %% [markdown]
# ## Fichero p654

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "p654"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: p654
# Limite iteraciones: 52320
# Tiempo de ejecución: 12.449500
#
# 1)	Coste: 346628 	 #EV: 52320 	 Semilla: 60564
# 2)	Coste: 321223 	 #EV: 52320 	 Semilla: 4172274
# 3)	Coste: 336598 	 #EV: 52320 	 Semilla: 8709592
# 4)	Coste: 316380 	 #EV: 52320 	 Semilla: 8674316
# 5)	Coste: 343343 	 #EV: 52320 	 Semilla: 7927296
# 6)	Coste: 313882 	 #EV: 52320 	 Semilla: 3604392
# 7)	Coste: 262763 	 #EV: 52320 	 Semilla: 4625181
# 8)	Coste: 300437 	 #EV: 52320 	 Semilla: 8620343
# 9)	Coste: 283542 	 #EV: 52320 	 Semilla: 1024116
# 10)	Coste: 353024 	 #EV: 52320 	 Semilla: 610738
# -----
# Coste Media:	317782.000000 	 Desv: 29080.023552
# #Ev Media:	52320.000000 	 Desv: 0.000000
# Mejor solución de coste:  262763

# %% [markdown]
# ## Fichero vm1084

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "vm1084"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: vm1084
# Limite iteraciones: 86720
# Tiempo de ejecución: 21.525500
#
# 1)	Coste: 1254683 	 #EV: 86720 	 Semilla: 60564
# 2)	Coste: 1306200 	 #EV: 86720 	 Semilla: 4172274
# 3)	Coste: 1206424 	 #EV: 86720 	 Semilla: 8709592
# 4)	Coste: 1312050 	 #EV: 86720 	 Semilla: 8674316
# 5)	Coste: 1255445 	 #EV: 86720 	 Semilla: 7927296
# 6)	Coste: 1256615 	 #EV: 86720 	 Semilla: 3604392
# 7)	Coste: 1338345 	 #EV: 86720 	 Semilla: 4625181
# 8)	Coste: 1249573 	 #EV: 86720 	 Semilla: 8620343
# 9)	Coste: 1315818 	 #EV: 86720 	 Semilla: 1024116
# 10)	Coste: 1368740 	 #EV: 86720 	 Semilla: 610738
# -----
# Coste Media:	1286389.300000 	 Desv: 49438.237055
# #Ev Media:	86720.000000 	 Desv: 0.000000
# Mejor solución de coste:  1206424

# %% [markdown]
# ## Fichero vm1748

# %%
algoritmo = "algoritmoEnfriamientoSimulado"
print(algoritmo)
fichero = "vm1748"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 80 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=6) as p:
    resultados = p.starmap(algoritmoEnfriamientoSimulado, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# algoritmoEnfriamientoSimulado
#
# Fichero: vm1748
# Limite iteraciones: 139840
# Tiempo de ejecución: 36.374998
#
# 1)	Coste: 2315263 	 #EV: 139840 	 Semilla: 60564
# 2)	Coste: 2280860 	 #EV: 139840 	 Semilla: 4172274
# 3)	Coste: 2400820 	 #EV: 139840 	 Semilla: 8709592
# 4)	Coste: 2263512 	 #EV: 139840 	 Semilla: 8674316
# 5)	Coste: 2294621 	 #EV: 139840 	 Semilla: 7927296
# 6)	Coste: 2316322 	 #EV: 139840 	 Semilla: 3604392
# 7)	Coste: 2240709 	 #EV: 139840 	 Semilla: 4625181
# 8)	Coste: 2228718 	 #EV: 139840 	 Semilla: 8620343
# 9)	Coste: 2355339 	 #EV: 139840 	 Semilla: 1024116
# 10)	Coste: 2369259 	 #EV: 139840 	 Semilla: 610738
# -----
# Coste Media:	2306542.300000 	 Desv: 56192.555806
# #Ev Media:	139840.000000 	 Desv: 0.000000
# Mejor solución de coste:  2228718

# %% [markdown]
# # Búsqueda Local Mejor Vecino

# %%
import import_ipynb
from algoritmos import *
# Out:
# importing Jupyter notebook from algoritmos.ipynb

# %% [markdown]
# ## Generación de semillas aleatorias

# %%
semillas = []
for i in range(10):
    semillas.append(random.randint(0,9999999))

# %% [markdown]
# ## Fichero st70

# %%
algoritmo = "busquedaLocalMejorVecino"
print(algoritmo)
fichero = "st70"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaLocalMejorVecino_v2, product([distancias], semillas, [nIteraciones]))



#for s in semillas:
    
#resultados = [busquedaLocalMejorVecino_v2(distancias, 1,nIteraciones)]
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaLocalMejorVecino
#
# Fichero: st70
# Limite iteraciones: 112000
# Tiempo de ejecución: 1.581002
#
# 1)	Coste: 1173 	 #EV: 113505 	 Semilla: 8307796
# 2)	Coste: 1224 	 #EV: 113505 	 Semilla: 5145909
# 3)	Coste: 1190 	 #EV: 113505 	 Semilla: 9829141
# 4)	Coste: 1130 	 #EV: 113505 	 Semilla: 5840894
# 5)	Coste: 1194 	 #EV: 113505 	 Semilla: 5086812
# 6)	Coste: 1156 	 #EV: 113505 	 Semilla: 8084775
# 7)	Coste: 1259 	 #EV: 113505 	 Semilla: 210351
# 8)	Coste: 1157 	 #EV: 113505 	 Semilla: 1855851
# 9)	Coste: 1056 	 #EV: 113505 	 Semilla: 6638255
# 10)	Coste: 1276 	 #EV: 113505 	 Semilla: 2387311
# -----
# Coste Media:	1181.500000 	 Desv: 63.854435
# #Ev Media:	113505.000000 	 Desv: 0.000000
# Mejor solución de coste:  1056

# %% [markdown]
# ## Fichero ch130

# %%
algoritmo = "busquedaLocalMejorVecino"
print(algoritmo)
fichero = "ch130"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaLocalMejorVecino_v2, product([distancias], semillas, [nIteraciones]))



#for s in semillas:
    
#resultados = [busquedaLocalMejorVecino_v2(distancias, 1,nIteraciones)]
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaLocalMejorVecino
#
# Fichero: ch130
# Limite iteraciones: 208000
# Tiempo de ejecución: 1.841001
#
# 1)	Coste: 22094 	 #EV: 209625 	 Semilla: 8307796
# 2)	Coste: 22914 	 #EV: 209625 	 Semilla: 5145909
# 3)	Coste: 24253 	 #EV: 209625 	 Semilla: 9829141
# 4)	Coste: 24196 	 #EV: 209625 	 Semilla: 5840894
# 5)	Coste: 22502 	 #EV: 209625 	 Semilla: 5086812
# 6)	Coste: 24078 	 #EV: 209625 	 Semilla: 8084775
# 7)	Coste: 23038 	 #EV: 209625 	 Semilla: 210351
# 8)	Coste: 25236 	 #EV: 209625 	 Semilla: 1855851
# 9)	Coste: 23045 	 #EV: 209625 	 Semilla: 6638255
# 10)	Coste: 23378 	 #EV: 209625 	 Semilla: 2387311
# -----
# Coste Media:	23473.400000 	 Desv: 951.240033
# #Ev Media:	209625.000000 	 Desv: 0.000000
# Mejor solución de coste:  22094

# %% [markdown]
# ## Fichero a280

# %%
algoritmo = "busquedaLocalMejorVecino"
print(algoritmo)
fichero = "a280"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaLocalMejorVecino_v2, product([distancias], semillas, [nIteraciones]))



#for s in semillas:
    
#resultados = [busquedaLocalMejorVecino_v2(distancias, 1,nIteraciones)]
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaLocalMejorVecino
#
# Fichero: a280
# Limite iteraciones: 448000
# Tiempo de ejecución: 2.820997
#
# 1)	Coste: 26412 	 #EV: 468720 	 Semilla: 4346140
# 2)	Coste: 24998 	 #EV: 468720 	 Semilla: 2298741
# 3)	Coste: 26666 	 #EV: 468720 	 Semilla: 5428347
# 4)	Coste: 27215 	 #EV: 468720 	 Semilla: 4392375
# 5)	Coste: 26931 	 #EV: 468720 	 Semilla: 8870551
# 6)	Coste: 26520 	 #EV: 468720 	 Semilla: 9827348
# 7)	Coste: 25446 	 #EV: 468720 	 Semilla: 8514779
# 8)	Coste: 26954 	 #EV: 468720 	 Semilla: 2338857
# 9)	Coste: 25677 	 #EV: 468720 	 Semilla: 2814383
# 10)	Coste: 27366 	 #EV: 468720 	 Semilla: 6963517
# -----
# Coste Media:	26418.500000 	 Desv: 793.486295
# #Ev Media:	468720.000000 	 Desv: 0.000000
# Mejor solución de coste:  24998

# %% [markdown]
# ## Fichero p654

# %%
algoritmo = "busquedaLocalMejorVecino"
print(algoritmo)
fichero = "p654"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaLocalMejorVecino_v2, product([distancias], semillas, [nIteraciones]))



#for s in semillas:
    
#resultados = [busquedaLocalMejorVecino_v2(distancias, 1,nIteraciones)]
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaLocalMejorVecino
#
# Fichero: p654
# Limite iteraciones: 1046400
# Tiempo de ejecución: 4.818500
#
# 1)	Coste: 1913102 	 #EV: 1067655 	 Semilla: 4346140
# 2)	Coste: 1874183 	 #EV: 1067655 	 Semilla: 2298741
# 3)	Coste: 1954410 	 #EV: 1067655 	 Semilla: 5428347
# 4)	Coste: 2030531 	 #EV: 1067655 	 Semilla: 4392375
# 5)	Coste: 1973411 	 #EV: 1067655 	 Semilla: 8870551
# 6)	Coste: 1913706 	 #EV: 1067655 	 Semilla: 9827348
# 7)	Coste: 2011963 	 #EV: 1067655 	 Semilla: 8514779
# 8)	Coste: 1938008 	 #EV: 1067655 	 Semilla: 2338857
# 9)	Coste: 1990716 	 #EV: 1067655 	 Semilla: 2814383
# 10)	Coste: 1863563 	 #EV: 1067655 	 Semilla: 6963517
# -----
# Coste Media:	1946359.300000 	 Desv: 56233.166769
# #Ev Media:	1067655.000000 	 Desv: 0.000000
# Mejor solución de coste:  1863563

# %% [markdown]
# ## Fichero vm1084

# %%
algoritmo = "busquedaLocalMejorVecino"
print(algoritmo)
fichero = "vm1084"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaLocalMejorVecino_v2, product([distancias], semillas, [nIteraciones]))



#for s in semillas:
    
#resultados = [busquedaLocalMejorVecino_v2(distancias, 1,nIteraciones)]
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaLocalMejorVecino
#
# Fichero: vm1084
# Limite iteraciones: 1734400
# Tiempo de ejecución: 7.046501
#
# 1)	Coste: 8454398 	 #EV: 1760958 	 Semilla: 4346140
# 2)	Coste: 8441813 	 #EV: 1760958 	 Semilla: 2298741
# 3)	Coste: 8366794 	 #EV: 1760958 	 Semilla: 5428347
# 4)	Coste: 8402660 	 #EV: 1760958 	 Semilla: 4392375
# 5)	Coste: 8376210 	 #EV: 1760958 	 Semilla: 8870551
# 6)	Coste: 8466410 	 #EV: 1760958 	 Semilla: 9827348
# 7)	Coste: 8366279 	 #EV: 1760958 	 Semilla: 8514779
# 8)	Coste: 8208834 	 #EV: 1760958 	 Semilla: 2338857
# 9)	Coste: 8148831 	 #EV: 1760958 	 Semilla: 2814383
# 10)	Coste: 8367801 	 #EV: 1760958 	 Semilla: 6963517
# -----
# Coste Media:	8360003.000000 	 Desv: 103601.814162
# #Ev Media:	1760958.000000 	 Desv: 0.000000
# Mejor solución de coste:  8148831

# %% [markdown]
# ## Fichero vm1748

# %%
algoritmo = "busquedaLocalMejorVecino"
print(algoritmo)
fichero = "vm1748"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaLocalMejorVecino_v2, product([distancias], semillas, [nIteraciones]))



#for s in semillas:
    
#resultados = [busquedaLocalMejorVecino_v2(distancias, 1,nIteraciones)]
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaLocalMejorVecino
#
# Fichero: vm1748
# Limite iteraciones: 2796800
# Tiempo de ejecución: 11.794998
#
# 1)	Coste: 15133126 	 #EV: 3053756 	 Semilla: 4688369
# 2)	Coste: 15016535 	 #EV: 3053756 	 Semilla: 201967
# 3)	Coste: 14738116 	 #EV: 3053756 	 Semilla: 756812
# 4)	Coste: 14816225 	 #EV: 3053756 	 Semilla: 9444884
# 5)	Coste: 15018962 	 #EV: 3053756 	 Semilla: 7926831
# 6)	Coste: 14976830 	 #EV: 3053756 	 Semilla: 153232
# 7)	Coste: 14828772 	 #EV: 3053756 	 Semilla: 6575218
# 8)	Coste: 14872157 	 #EV: 3053756 	 Semilla: 7904492
# 9)	Coste: 14795905 	 #EV: 3053756 	 Semilla: 8509222
# 10)	Coste: 14670935 	 #EV: 3053756 	 Semilla: 304286
# -----
# Coste Media:	14886756.300000 	 Desv: 144763.743355
# #Ev Media:	3053756.000000 	 Desv: 0.000000
# Mejor solución de coste:  14670935

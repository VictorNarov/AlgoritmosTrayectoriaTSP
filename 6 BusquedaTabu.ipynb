# %% [markdown]
# # Búsqueda Tabú

# %%
import import_ipynb
from algoritmos import *

# %% [markdown]
# ## Generación de semillas aleatorias

# %%
semillas = []
for i in range(10):
    semillas.append(random.randint(0,9999999))

# %% [markdown]
# ## Fichero st70

# %%
algoritmo = "busquedaTabu"
print(algoritmo)
fichero = "st70"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 40 * len(nodos)

print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')


t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaTabu, product([distancias], semillas, [nIteraciones]))
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )


for i,res in enumerate(resultados):
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaTabu
#
# Fichero: st70
# Limite iteraciones: 2800
# Tiempo de ejecución: 2.448498
#
# 1)	Coste: 980 	 #EV: 112003 	 Semilla: 7529288
# 2)	Coste: 1073 	 #EV: 112004 	 Semilla: 421173
# 3)	Coste: 992 	 #EV: 112005 	 Semilla: 2540047
# 4)	Coste: 1022 	 #EV: 112004 	 Semilla: 2028326
# 5)	Coste: 1023 	 #EV: 112005 	 Semilla: 6711843
# 6)	Coste: 1065 	 #EV: 112004 	 Semilla: 4185848
# 7)	Coste: 989 	 #EV: 112004 	 Semilla: 7150037
# 8)	Coste: 1013 	 #EV: 112003 	 Semilla: 9284840
# 9)	Coste: 1076 	 #EV: 112005 	 Semilla: 2526298
# 10)	Coste: 976 	 #EV: 112004 	 Semilla: 5645229
# -----
# Coste Media:	1020.900000 	 Desv: 38.448956
# #Ev Media:	112004.100000 	 Desv: 0.737865
# Mejor solución de coste:  976

# %% [markdown]
# ## Fichero ch130

# %%
algoritmo = "busquedaTabu"
print(algoritmo)
fichero = "ch130"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 40 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')


t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaTabu, product([distancias], semillas, [nIteraciones]))
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )


for i,res in enumerate(resultados):
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaTabu
#
# Fichero: ch130
# Limite iteraciones: 5200
# Tiempo de ejecución: 5.035000
#
# 1)	Coste: 10250 	 #EV: 208004 	 Semilla: 7529288
# 2)	Coste: 11195 	 #EV: 208004 	 Semilla: 421173
# 3)	Coste: 11310 	 #EV: 208004 	 Semilla: 2540047
# 4)	Coste: 10306 	 #EV: 208003 	 Semilla: 2028326
# 5)	Coste: 9992 	 #EV: 208005 	 Semilla: 6711843
# 6)	Coste: 11285 	 #EV: 208005 	 Semilla: 4185848
# 7)	Coste: 10330 	 #EV: 208005 	 Semilla: 7150037
# 8)	Coste: 10816 	 #EV: 208004 	 Semilla: 9284840
# 9)	Coste: 10856 	 #EV: 208003 	 Semilla: 2526298
# 10)	Coste: 10890 	 #EV: 208004 	 Semilla: 5645229
# -----
# Coste Media:	10723.000000 	 Desv: 474.207175
# #Ev Media:	208004.100000 	 Desv: 0.737865
# Mejor solución de coste:  9992

# %% [markdown]
# ## Fichero a280

# %%
algoritmo = "busquedaTabu"
print(algoritmo)
fichero = "a280"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 40 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')


t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaTabu, product([distancias], semillas, [nIteraciones]))
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )


for i,res in enumerate(resultados):
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaTabu
#
# Fichero: a280
# Limite iteraciones: 11200
# Tiempo de ejecución: 11.413000
#
# 1)	Coste: 7122 	 #EV: 448004 	 Semilla: 7529288
# 2)	Coste: 2996 	 #EV: 448004 	 Semilla: 421173
# 3)	Coste: 2879 	 #EV: 448004 	 Semilla: 2540047
# 4)	Coste: 3245 	 #EV: 448004 	 Semilla: 2028326
# 5)	Coste: 2868 	 #EV: 448003 	 Semilla: 6711843
# 6)	Coste: 3474 	 #EV: 448005 	 Semilla: 4185848
# 7)	Coste: 3034 	 #EV: 448004 	 Semilla: 7150037
# 8)	Coste: 3126 	 #EV: 448003 	 Semilla: 9284840
# 9)	Coste: 3141 	 #EV: 448005 	 Semilla: 2526298
# 10)	Coste: 3466 	 #EV: 448003 	 Semilla: 5645229
# -----
# Coste Media:	3535.100000 	 Desv: 1277.950395
# #Ev Media:	448003.900000 	 Desv: 0.737865
# Mejor solución de coste:  2868

# %% [markdown]
# ## Fichero p654

# %%
algoritmo = "busquedaTabu"
print(algoritmo)
fichero = "p654"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 40 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')


t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaTabu, product([distancias], semillas, [nIteraciones]))
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )


for i,res in enumerate(resultados):
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaTabu
#
# Fichero: p654
# Limite iteraciones: 26160
# Tiempo de ejecución: 63.425996
#
# 1)	Coste: 98462 	 #EV: 1046404 	 Semilla: 7529288
# 2)	Coste: 329114 	 #EV: 1046403 	 Semilla: 421173
# 3)	Coste: 99219 	 #EV: 1046404 	 Semilla: 2540047
# 4)	Coste: 100353 	 #EV: 1046404 	 Semilla: 2028326
# 5)	Coste: 328567 	 #EV: 1046401 	 Semilla: 6711843
# 6)	Coste: 103497 	 #EV: 1046404 	 Semilla: 4185848
# 7)	Coste: 348415 	 #EV: 1046404 	 Semilla: 7150037
# 8)	Coste: 102587 	 #EV: 1046405 	 Semilla: 9284840
# 9)	Coste: 339662 	 #EV: 1046402 	 Semilla: 2526298
# 10)	Coste: 100851 	 #EV: 1046403 	 Semilla: 5645229
# -----
# Coste Media:	195072.700000 	 Desv: 121800.633046
# #Ev Media:	1046403.400000 	 Desv: 1.173788
# Mejor solución de coste:  98462

# %% [markdown]
# ## Fichero vm1084

# %%
algoritmo = "busquedaTabu"
print(algoritmo)
fichero = "vm1084"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 40 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')


t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaTabu, product([distancias], semillas, [nIteraciones]))
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )


for i,res in enumerate(resultados):
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaTabu
#
# Fichero: vm1084
# Limite iteraciones: 43360
# Tiempo de ejecución: 161.339502
#
# 1)	Coste: 1493573 	 #EV: 1734405 	 Semilla: 7529288
# 2)	Coste: 1469902 	 #EV: 1734404 	 Semilla: 421173
# 3)	Coste: 1395645 	 #EV: 1734403 	 Semilla: 2540047
# 4)	Coste: 1416843 	 #EV: 1734404 	 Semilla: 2028326
# 5)	Coste: 1367140 	 #EV: 1734403 	 Semilla: 6711843
# 6)	Coste: 1469118 	 #EV: 1734404 	 Semilla: 4185848
# 7)	Coste: 1404381 	 #EV: 1734404 	 Semilla: 7150037
# 8)	Coste: 1503934 	 #EV: 1734404 	 Semilla: 9284840
# 9)	Coste: 1566976 	 #EV: 1734405 	 Semilla: 2526298
# 10)	Coste: 1470293 	 #EV: 1734404 	 Semilla: 5645229
# -----
# Coste Media:	1455780.500000 	 Desv: 59935.932712
# #Ev Media:	1734404.000000 	 Desv: 0.666667
# Mejor solución de coste:  1367140

# %% [markdown]
# ## Fichero vm1748

# %%
algoritmo = "busquedaTabu"
print(algoritmo)
fichero = "vm1748"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 40 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')


t = time.time()
with Pool(processes=10) as p:
     resultados = p.starmap(busquedaTabu, product([distancias], semillas, [nIteraciones]))
    
elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )


for i,res in enumerate(resultados):
    costes.append(res[1])
    evs.append(res[2])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t #EV: %i \t Semilla: %s" % (i+1,res[1], res[2], res[3]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("#Ev Media:\t%f \t Desv: %f" % (mean(evs), stdev(evs)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaTabu
#
# Fichero: vm1748
# Limite iteraciones: 69920
# Tiempo de ejecución: 485.863999
#
# 1)	Coste: 2570327 	 #EV: 2796804 	 Semilla: 7529288
# 2)	Coste: 2409871 	 #EV: 2796802 	 Semilla: 421173
# 3)	Coste: 2696201 	 #EV: 2796804 	 Semilla: 2540047
# 4)	Coste: 2303177 	 #EV: 2796804 	 Semilla: 2028326
# 5)	Coste: 2641385 	 #EV: 2796804 	 Semilla: 6711843
# 6)	Coste: 2604359 	 #EV: 2796805 	 Semilla: 4185848
# 7)	Coste: 2660937 	 #EV: 2796805 	 Semilla: 7150037
# 8)	Coste: 2436246 	 #EV: 2796804 	 Semilla: 9284840
# 9)	Coste: 2613595 	 #EV: 2796804 	 Semilla: 2526298
# 10)	Coste: 2338296 	 #EV: 2796804 	 Semilla: 5645229
# -----
# Coste Media:	2527439.400000 	 Desv: 142467.095542
# #Ev Media:	2796804.000000 	 Desv: 0.816497
# Mejor solución de coste:  2303177

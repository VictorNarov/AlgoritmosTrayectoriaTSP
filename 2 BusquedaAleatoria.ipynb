# %% [markdown]
# # Búsqueda Local Primer Mejor Vecino

# %%
import import_ipynb
from algoritmos import *
# Out:
# importing Jupyter notebook from algoritmos.ipynb

# %% [markdown]
# ## Generación de semillas aleatorias

# %%
semillas = []
for i in range(10):
    semillas.append(random.randint(0,9999999))

# %% [markdown]
# ## Fichero st70

# %%
algoritmo = "busquedaAleatoria"
print(algoritmo)
fichero = "st70"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=10) as p:
    resultados = p.starmap(busquedaAleatoria_v2, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t Semilla: %s" % (i+1,res[1], res[2]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaAleatoria
#
# Fichero: st70
# Limite iteraciones: 112000
# Tiempo de ejecución: 8.300501
#
# 1)	Coste: 2863 	 Semilla: 9328070
# 2)	Coste: 2939 	 Semilla: 1293337
# 3)	Coste: 2819 	 Semilla: 8669624
# 4)	Coste: 2699 	 Semilla: 2824010
# 5)	Coste: 2872 	 Semilla: 1149148
# 6)	Coste: 2833 	 Semilla: 134468
# 7)	Coste: 2861 	 Semilla: 7048250
# 8)	Coste: 2814 	 Semilla: 7407443
# 9)	Coste: 2928 	 Semilla: 5110905
# 10)	Coste: 2819 	 Semilla: 8148497
# -----
# Coste Media:	2844.700000 	 Desv: 67.335066
# Mejor solución de coste:  2699

# %% [markdown]
# ## Fichero ch130

# %%
algoritmo = "busquedaAleatoria"
print(algoritmo)
fichero = "ch130"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=10) as p:
    resultados = p.starmap(busquedaAleatoria_v2, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t Semilla: %s" % (i+1,res[1], res[2]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = "Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaAleatoria
#
# Fichero: ch130
# Limite iteraciones: 208000
# Tiempo de ejecución: 24.095506
#
# 1)	Coste: 38476 	 Semilla: 9328070
# 2)	Coste: 39419 	 Semilla: 1293337
# 3)	Coste: 38810 	 Semilla: 8669624
# 4)	Coste: 39145 	 Semilla: 2824010
# 5)	Coste: 38504 	 Semilla: 1149148
# 6)	Coste: 38617 	 Semilla: 134468
# 7)	Coste: 38754 	 Semilla: 7048250
# 8)	Coste: 38933 	 Semilla: 7407443
# 9)	Coste: 38802 	 Semilla: 5110905
# 10)	Coste: 38319 	 Semilla: 8148497
# -----
# Coste Media:	38777.900000 	 Desv: 329.081702
# Mejor solución de coste:  38319

# %% [markdown]
# ## Fichero a280

# %%
print("busquedaAleatoria")
fichero = "a280"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=10) as p:
    resultados = p.starmap(busquedaAleatoria_v2, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t Semilla: %s" % (i+1,res[1], res[2]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaAleatoria
#
# Fichero: a280
# Limite iteraciones: 448000
# Tiempo de ejecución: 93.639997
#
# 1)	Coste: 29733 	 Semilla: 3023229
# 2)	Coste: 29959 	 Semilla: 9145821
# 3)	Coste: 29541 	 Semilla: 2030883
# 4)	Coste: 29428 	 Semilla: 9107397
# 5)	Coste: 28949 	 Semilla: 1026037
# 6)	Coste: 29621 	 Semilla: 4884751
# 7)	Coste: 29179 	 Semilla: 800162
# 8)	Coste: 29520 	 Semilla: 2499101
# 9)	Coste: 28712 	 Semilla: 2805795
# 10)	Coste: 29751 	 Semilla: 5712678
# -----
# Coste Media:	29439.300000 	 Desv: 385.950213

# %% [markdown]
# ## Fichero p654

# %%
print("busquedaAleatoria")
fichero = "p654"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=10) as p:
    resultados = p.starmap(busquedaAleatoria_v2, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t Semilla: %s" % (i+1,res[1], res[2]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("Mejor solución de coste: ", str(mejorCoste))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaAleatoria
#
# Fichero: p654
# Limite iteraciones: 1046400

# %% [markdown]
# ## Fichero vm1084

# %%
print("busquedaAleatoria")
fichero = "vm1084"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=10) as p:
    resultados = p.starmap(busquedaAleatoria_v2, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t Semilla: %s" % (i+1,res[1], res[2]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaLocalPrimerMejorVecino
#
# Fichero: vm1084
# Limite iteraciones: 1734400
# Tiempo de ejecución: 6.594004
#
# 1)	Coste: 3646783 	 #EV: 1735595 	 Semilla: 7555878
# 2)	Coste: 2975823 	 #EV: 1734421 	 Semilla: 3172574
# 3)	Coste: 2964170 	 #EV: 1734411 	 Semilla: 1226396
# 4)	Coste: 5946583 	 #EV: 1735372 	 Semilla: 897130
# 5)	Coste: 3158648 	 #EV: 1734447 	 Semilla: 9618576
# 6)	Coste: 3506826 	 #EV: 1734609 	 Semilla: 8197606
# 7)	Coste: 3223207 	 #EV: 1734643 	 Semilla: 4844204
# 8)	Coste: 4822629 	 #EV: 1739608 	 Semilla: 4944858
# 9)	Coste: 3210350 	 #EV: 1734986 	 Semilla: 4980488
# 10)	Coste: 3142259 	 #EV: 1734420 	 Semilla: 1468054
# -----
# Coste Media:	3659727.800000 	 Desv: 970020.882051
# #Ev Media:	1735251.200000 	 Desv: 1588.149013

# %% [markdown]
# ## Fichero vm1748

# %%
print("busquedaAleatoria")
fichero = "vm1748"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
nIteraciones = 1600 * len(nodos)
    
print(f"\nFichero: {fichero}\nLimite iteraciones: {nIteraciones}")

costes = []
evs = []
mejorSolucion = []
mejorCoste = float('inf')

t = time.time()

with Pool(processes=10) as p:
    resultados = p.starmap(busquedaAleatoria_v2, product([distancias], semillas, [nIteraciones]))
    

elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

i=0
for res in resultados:
    costes.append(res[1])
    
    if res[1] < mejorCoste:
        mejorCoste = res[1] 
        mejorSolucion = res[0]

    #coste = getCosteCamino(camino, distancias)
    print("%i)\tCoste: %s \t Semilla: %s" % (i+1,res[1], res[2]) ) 
    #print("Camino: " + str(camino))
    # pintaCamino(camino,nodos)
    i+=1

print("-----\nCoste Media:\t%f \t Desv: %f" % (mean(costes), stdev(costes)))
print("Mejor solución de coste: ", str(mejorCoste))
titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(mejorCoste)
pintaCamino(mejorSolucion, nodos, titulo)
# Out:
# busquedaLocalPrimerMejorVecino
#
# Fichero: vm1748
# Limite iteraciones: 2796800
# Tiempo de ejecución: 10.269996
#
# 1)	Coste: 8243456 	 #EV: 2796802 	 Semilla: 7555878
# 2)	Coste: 8157638 	 #EV: 2797092 	 Semilla: 3172574
# 3)	Coste: 7975477 	 #EV: 2796879 	 Semilla: 1226396
# 4)	Coste: 7983774 	 #EV: 2796830 	 Semilla: 897130
# 5)	Coste: 7640664 	 #EV: 2797081 	 Semilla: 9618576
# 6)	Coste: 7548014 	 #EV: 2797680 	 Semilla: 8197606
# 7)	Coste: 7883948 	 #EV: 2796937 	 Semilla: 4844204
# 8)	Coste: 7791312 	 #EV: 2797476 	 Semilla: 4944858
# 9)	Coste: 7936133 	 #EV: 2796967 	 Semilla: 4980488
# 10)	Coste: 7795509 	 #EV: 2797342 	 Semilla: 1468054
# -----
# Coste Media:	7895592.500000 	 Desv: 214036.336202
# #Ev Media:	2797108.600000 	 Desv: 296.428444

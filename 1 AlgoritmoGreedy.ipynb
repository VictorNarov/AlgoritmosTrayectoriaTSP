# %% [markdown]
# # Algoritmo Greedy

# %%
import import_ipynb
from algoritmos import *

# %% [markdown]
# ## Fichero st70

# %%
algoritmo = "algoritmoGreedy"
print(algoritmo)
fichero = "st70"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
   

t = time.time()
with Pool(processes=10) as p:
     camino = p.starmap(algoritmoGreedy, product([distancias]))[0]


elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

coste = getCosteCamino(camino,distancias)

titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(coste)
print("Coste: %s" % (coste) ) 
#print("Camino: " + str(camino))
pintaCamino(camino,nodos,titulo)
# Out:
# algoritmoGreedy
# Tiempo de ejecución: 1.067504
#
# Coste: 830

# %% [markdown]
# ## Fichero ch130

# %%
algoritmo = "algoritmoGreedy"
print(algoritmo)
fichero = "ch130"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
   

t = time.time()
with Pool(processes=10) as p:
     camino = p.starmap(algoritmoGreedy, product([distancias]))[0]


elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

coste = getCosteCamino(camino,distancias)

titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(coste)
print("Coste: %s" % (coste) ) 
#print("Camino: " + str(camino))
pintaCamino(camino,nodos,titulo)
# Out:
# algoritmoGreedy
# Tiempo de ejecución: 1.106998
#
# Coste: 7579

# %% [markdown]
# ## Fichero a280

# %%
algoritmo = "algoritmoGreedy"
print(algoritmo)
fichero = "a280"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
   

t = time.time()
with Pool(processes=10) as p:
     camino = p.starmap(algoritmoGreedy, product([distancias]))[0]


elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

coste = getCosteCamino(camino,distancias)

titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(coste)
print("Coste: %s" % (coste) ) 
#print("Camino: " + str(camino))
pintaCamino(camino,nodos,titulo)
# Out:
# algoritmoGreedy
# Tiempo de ejecución: 1.137001
#
# Coste: 3157

# %% [markdown]
# ## Fichero p654

# %%
algoritmo = "algoritmoGreedy"
print(algoritmo)
fichero = "p654"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
   

t = time.time()
with Pool(processes=10) as p:
     camino = p.starmap(algoritmoGreedy, product([distancias]))[0]


elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

coste = getCosteCamino(camino,distancias)
print(len(camino))

titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(coste)
print("Coste: %s" % (coste) ) 
#print("Camino: " + str(camino))
pintaCamino(camino,nodos,titulo)
# Out:
# algoritmoGreedy
# Tiempo de ejecución: 1.089499
#
# 654
# Coste: 43457

# %% [markdown]
# ## Fichero vm1084

# %%
algoritmo = "algoritmoGreedy"
print(algoritmo)
fichero = "vm1084"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
   

t = time.time()
with Pool(processes=10) as p:
     camino = p.starmap(algoritmoGreedy, product([distancias]))[0]


elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

coste = getCosteCamino(camino,distancias)

titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(coste)
print("Coste: %s" % (coste) ) 
#print("Camino: " + str(camino))
pintaCamino(camino,nodos,titulo)
# Out:
# algoritmoGreedy
# Tiempo de ejecución: 1.176503
#
# Coste: 301476

# %% [markdown]
# ## Fichero vm1748

# %%
algoritmo = "algoritmoGreedy"
print(algoritmo)
fichero = "vm1748"
#,"a280","p654","vm1084","vm1748"
nodos = leeFichero(fichero)
distancias = getMDistancias(nodos)
   

t = time.time()
with Pool(processes=10) as p:
     camino = p.starmap(algoritmoGreedy, product([distancias]))[0]


elapsed = time.time() - t
print("Tiempo de ejecución: %f\n" % elapsed )

coste = getCosteCamino(camino,distancias)

titulo = algoritmo + " - Mejor solución " + fichero + ": " + str(coste)
print("Coste: %s" % (coste) ) 
#print("Camino: " + str(camino))
pintaCamino(camino,nodos,titulo)
# Out:
# algoritmoGreedy
# Tiempo de ejecución: 1.223998
#
# Coste: 408101
